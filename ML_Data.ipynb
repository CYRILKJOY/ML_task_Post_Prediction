# %% [markdown]
# # Importing libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Importing data set

# %%
users=pd.read_csv("C:\\Users\\admin\\Downloads\\Mldata\\users.csv")
views=pd.read_csv("C:\\Users\\admin\\Downloads\\Mldata\\views.csv")
posts=pd.read_csv("C:\\Users\\admin\\Downloads\\Mldata\\posts.csv")

# %% [markdown]
# # users.csv

# %%
users.head(10)
# Out:
#                         _id                  name  gender      academics
# 0  5d60098a653a331687083238  Nivesh Singh Chauhan    male  undergraduate
# 1  5d610ae1653a331687083239         Gaurav Sharma    male       graduate
# 2  5d618359fc5fcf3bdd9a0910         Akshay Mishra    male  undergraduate
# 3  5d6d2bb87fa40e1417a49315        Saksham Mathur    male  undergraduate
# 4  5d7c994d5720533e15c3b1e9         Varun Chowhan    male  undergraduate
# 5  5d90fc1a641ef364939fb6cc          Boshi Kaviya  female       graduate
# 6  5d9a2982979d5962253c2f81       Nischaya Sharma    male  undergraduate
# 7  5de50d768eab6401affbb135      thesocialcomment    male       graduate
# 8  5ded443342a8854bf6eaba9a    MAAZ AHMAD RABBANI    male  undergraduate
# 9  5deeef6142a8854bf6eabab9      siddharth saxena    male  undergraduate

# %% [markdown]
# # Views.csv

# %%
views.head(10)
# Out:
#                     user_id                   post_id  \
# 0  5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1  5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2  5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3  5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4  5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
# 5  5ed0defa76027d35905cc2de  5ed23d4276027d35905cc798
# 6  5ed0defa76027d35905cc2de  5ed415c6bd514d602c15312d
# 7  5ecb979eeaff6b0c3a58a4f0  5ed229d976027d35905cc666
# 8  5ecb979eeaff6b0c3a58a4f0  5ed2502b76027d35905cc7db
# 9  5ecb979eeaff6b0c3a58a4f0  5ed13d2876027d35905cc4c2
#
#                   timestamp
# 0  2020-06-01T10:46:45.131Z
# 1  2020-06-01T09:39:20.021Z
# 2  2020-06-01T08:12:42.682Z
# 3  2020-06-01T08:10:23.880Z
# 4  2020-06-01T08:08:54.124Z
# 5  2020-06-01T08:07:22.659Z
# 6  2020-06-01T08:07:01.935Z
# 7  2020-05-31T20:44:07.524Z
# 8  2020-05-31T20:43:17.623Z
# 9  2020-05-31T20:42:38.962Z

# %% [markdown]
# # Posts.csv

# %%
posts.head(10)
# Out:
#                         _id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 4  5d80dfbc6c53455f896e600e   How Competition law evolved?
# 5  5d80e7c16c53455f896e6014     Raghavan Committee - 2002.
# 6  5d80ecfd6c53455f896e601a  Let's discuss some Case laws!
# 7  5d81323a6c53455f896e6044               Forms of Cartel.
# 8  5d9b3514979d5962253c2f90                   Biodiversity
# 9  5d9b950768671220a1b2b153                Economic policy
#
#                                             category  post_type
# 0                                Plant Biotechnology       blog
# 1  Artificial Intelligence|Machine Learning|Infor...       blog
# 2                                  Operating Systems       blog
# ...

# %%
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         493 non-null    object
#  1   title       493 non-null    object
#  2   category    465 non-null    object
#  3    post_type  493 non-null    object
# dtypes: object(4)
# memory usage: 15.5+ KB

# %%
posts.shape
# Out:
# (493, 4)

# %%
posts.columns=['post_id','title','category', 'post_type']

# %%
posts['category']=posts['category'].fillna('Project')

# %%
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   post_id    493 non-null    object
#  1   title      493 non-null    object
#  2   category   493 non-null    object
#  3   post_type  493 non-null    object
# dtypes: object(4)
# memory usage: 15.5+ KB

# %%
posts
# Out:
#                       post_id  \
# 0    5d62abaa65218653a132c956
# 1    5d6d39567fa40e1417a4931c
# 2    5d7d23315720533e15c3b1ee
# 3    5d7d405e5720533e15c3b1f3
# 4    5d80dfbc6c53455f896e600e
# ..                        ...
# 488  5ed3791976027d35905ccab6
# 489  5ed3820f76027d35905ccac8
# 490  5ed3ef4cbd514d602c1530f2
# 491  5ed415c6bd514d602c15312d
# 492  5ed4cbadbd514d602c1531a6
#
#                                                  title  \
# 0                                          hello there
# 1                                            Ml and AI
# 2                        What is an Operating System ?
# 3                                           Lord Shiva
# 4                         How Competition law evolved?
# ..                                                 ...
# 488                         CI/CD using GitHub Actions
# 489  Configure Docker with Django; PostgreSQL; Pg-a...
# 490                              Recommendation Engine
# ...

# %%
views.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    1449 non-null   object
#  1   post_id    1449 non-null   object
#  2   timestamp  1449 non-null   object
# dtypes: object(3)
# memory usage: 34.1+ KB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        118 non-null    object
#  1   name       118 non-null    object
#  2   gender     118 non-null    object
#  3   academics  118 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
users.columns=['user_id','name','gender', 'academics']

# %%
users
# Out:
#                       user_id                  name  gender      academics
# 0    5d60098a653a331687083238  Nivesh Singh Chauhan    male  undergraduate
# 1    5d610ae1653a331687083239         Gaurav Sharma    male       graduate
# 2    5d618359fc5fcf3bdd9a0910         Akshay Mishra    male  undergraduate
# 3    5d6d2bb87fa40e1417a49315        Saksham Mathur    male  undergraduate
# 4    5d7c994d5720533e15c3b1e9         Varun Chowhan    male  undergraduate
# ..                        ...                   ...     ...            ...
# 113  5ed35aa376027d35905cca67                 Steve    male       graduate
# 114  5ed3737976027d35905ccaa2        Himanshu Singh    male  undergraduate
# 115  5ed3748576027d35905ccaab           Parth Vijay    male  undergraduate
# 116  5ed3cbcbbd514d602c1530a7       Abhishek Mishra    male  undergraduate
# 117  5ed3e898bd514d602c1530de          gauri raskar  female       graduate
#
# [118 rows x 4 columns]

# %%
data=posts.merge(views,on='post_id',how='left')

# %%
data
# Out:
#                        post_id  \
# 0     5d62abaa65218653a132c956
# 1     5d6d39567fa40e1417a4931c
# 2     5d7d23315720533e15c3b1ee
# 3     5d7d23315720533e15c3b1ee
# 4     5d7d405e5720533e15c3b1f3
# ...                        ...
# 1442  5ed3820f76027d35905ccac8
# 1443  5ed3ef4cbd514d602c1530f2
# 1444  5ed415c6bd514d602c15312d
# 1445  5ed415c6bd514d602c15312d
# 1446  5ed4cbadbd514d602c1531a6
#
#                                                   title  \
# 0                                           hello there
# 1                                             Ml and AI
# 2                         What is an Operating System ?
# 3                         What is an Operating System ?
# 4                                            Lord Shiva
# ...                                                 ...
# 1442  Configure Docker with Django; PostgreSQL; Pg-a...
# 1443                              Recommendation Engine
# 1444          Face Recognition using Transfer Learning.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447 entries, 0 to 1446
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   post_id    1447 non-null   object
#  1   title      1447 non-null   object
#  2   category   1447 non-null   object
#  3   post_type  1447 non-null   object
#  4   user_id    1447 non-null   object
#  5   timestamp  1447 non-null   object
# dtypes: object(6)
# memory usage: 79.1+ KB

# %%
data=data.merge(users,on='user_id',how='left')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447 entries, 0 to 1446
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   post_id    1447 non-null   object
#  1   title      1447 non-null   object
#  2   category   1447 non-null   object
#  3   post_type  1447 non-null   object
#  4   user_id    1447 non-null   object
#  5   timestamp  1447 non-null   object
#  6   name       1447 non-null   object
#  7   gender     1447 non-null   object
#  8   academics  1447 non-null   object
# dtypes: object(9)
# memory usage: 113.0+ KB

# %%
data.shape
# Out:
# (1447, 9)

# %% [markdown]
# # Coimbined Data

# %%
data.head(10)
# Out:
#                     post_id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 4  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 5  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 6  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 7  5d80dfbc6c53455f896e600e   How Competition law evolved?
# 8  5d80dfbc6c53455f896e600e   How Competition law evolved?
# 9  5d80e7c16c53455f896e6014     Raghavan Committee - 2002.
#
#                                             category post_type  \
# 0                                Plant Biotechnology      blog
# 1  Artificial Intelligence|Machine Learning|Infor...      blog
# 2                                  Operating Systems      blog
# ...

# %% [markdown]
# # Deleting the unnecessary coloumns

# %%
data=data.drop(['timestamp','name'],axis=1)

# %%
data
# Out:
#                        post_id  \
# 0     5d62abaa65218653a132c956
# 1     5d6d39567fa40e1417a4931c
# 2     5d7d23315720533e15c3b1ee
# 3     5d7d23315720533e15c3b1ee
# 4     5d7d405e5720533e15c3b1f3
# ...                        ...
# 1442  5ed3820f76027d35905ccac8
# 1443  5ed3ef4cbd514d602c1530f2
# 1444  5ed415c6bd514d602c15312d
# 1445  5ed415c6bd514d602c15312d
# 1446  5ed4cbadbd514d602c1531a6
#
#                                                   title  \
# 0                                           hello there
# 1                                             Ml and AI
# 2                         What is an Operating System ?
# 3                         What is an Operating System ?
# 4                                            Lord Shiva
# ...                                                 ...
# 1442  Configure Docker with Django; PostgreSQL; Pg-a...
# 1443                              Recommendation Engine
# 1444          Face Recognition using Transfer Learning.
# ...

# %% [markdown]
# # Data Visualisation

# %%
data['gender'].value_counts()
# Out:
# male         997
# female       444
# undefined      6
# Name: gender, dtype: int64

# %% [markdown]
# # Post views based on the Gender

# %%
plt.style.use('seaborn-muted')
fig, ax = plt.subplots(1,2,figsize = (15,6))

sns.countplot('gender',data=data,ax=ax[0])
ax[0].set_title('Posts viewed by Gender')

data['gender'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1])
ax[1].set_title('Posts viewed by Gender')
ax[1].axis('equal') 

fig.tight_layout()
plt.show()

# %% [markdown]
# # Post type based on Gender

# %%
plt.figure(figsize=(15,6))
sns.countplot('post_type',data=data,hue='gender')
plt.title('posts type viewed based on Gender')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot('academics',data=data,hue='gender')
plt.title('Academics based on Gender')
plt.show()

# %%
data['category'].unique()
# Out:
# array(['Plant Biotechnology',
#        'Artificial Intelligence|Machine Learning|Information Technology',
#        'Operating Systems', 'Drawings', 'Competition Laws', 'Eco System',
#        'Economic Policies', 'Graphic|Graphic Design', 'Painting',
#        'Pen and ink', 'Computer Technology|Information Technology',
#        'Drawings|Painting',
#        'Graphic Design|Visual Arts|Illustration|Graphic',
#        'Drawings|Calligraphy', 'Photography', 'Empowerment', 'Project',
#        'Video editing', 'Inorganic Chemistry', 'Programming languages',
#        'Conceptual|Graphic Design', 'HR Management',
#        'Human Resources|HR Management',
#        'Mass Media|International Relations', 'Sculptures|Artistic design',
#        'Fashion Design|Ceramics|Artistic design', 'Craft|Artistic design',
#        'Fashion Design|Visual Arts|Conceptual|Artistic design',
#        'Photography|Fashion Design|Visual Arts|Graphic Design|Artistic design',
# ...

# %%
data['category'].value_counts()
# Out:
# Photography                             241
# Drawings                                149
# Project                                  88
# Painting                                 75
# Computer Technology|Machine Learning     40
#                                        ...
# Auditing|Secratarial Audit                1
# Mixed Media|Calligraphy|Pen and ink       1
# Auditing|Internal Audit                   1
# Graphic|Graphic Design                    1
# E Commerce|Other Online Platforms         1
# Name: category, Length: 232, dtype: int64

# %%
data['title'].unique()
# Out:
# array(['hello there', 'Ml and AI', 'What is an Operating System ?',
#        'Lord Shiva', 'How Competition law evolved?',
#        'Raghavan Committee - 2002.', "Let's discuss some Case laws!",
#        'Forms of Cartel.', 'Biodiversity', 'Economic policy',
#        'Corporate design', 'Trident', 'Lord shiva', 'Smart City',
#        'Om Namah Shivaay', 'Kid Bu', 'MIS', 'Portrait art',
#        'CLASSIFYING FORMS OF CARTELS', 'Best friend', 'Calligraphy',
#        'Colours of pushkar.', 'Marital Rape - Rape is Rape',
#        'Spirituality',
#        'Library Managment System: Software Requirement Specification (SRS)',
#        'Navigation system using BFS DFS algorithms', 'Shadow Sketch',
#        'Promotional video.', 'The Periodic Table',
#        'Computer Aided Machine Drawing (CAMD)', 'The Chosen',
#        'Python 3 Programming Introduction', 'Chat App UI Desgin',
#        'Workforce Diversity as a Challenge', 'Spartan',
# ...

# %% [markdown]
# # Prediction using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
CV=CountVectorizer()

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(posts['category'])

# %%
tf.get_feature_names()
# Out:
# ['2d',
#  '2d composition',
#  '2d composition logo',
#  '2d composition watercolours',
#  'abuse',
#  'abuse health',
#  'abuse health education',
#  'abuse social',
#  'abuse social interventions',
#  'accounting',
#  'accounting accounting',
#  'accounting accounting theory',
#  'accounting corporate',
#  'accounting corporate accounting',
#  'accounting financial',
#  'accounting financial accounting',
#  'accounting fundamental',
#  'accounting fundamental accounting',
#  'accounting partnership',
#  'accounting partnership accounting',
#  'accounting theory',
#  'accounting theory practices',
#  'acrylics',
#  'activity',
#  'activity creative',
#  'activity creative lateral',
#  'advertising',
#  'agreement',
#  'algebra',
#  'algorithms',
#  'algorithms programming',
#  'algorithms programming languages',
#  'algorithms web',
#  'algorithms web designing',
#  'alternate',
#  'alternate dispute',
#  'alternate dispute resolution',
#  'analysis',
#  'analysis algorithms',
# ...

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
postid = posts['post_id']
indices = pd.Series(posts.index, index=posts['post_id'])
indices.head()
# Out:
# post_id
# 5d62abaa65218653a132c956    0
# 5d6d39567fa40e1417a4931c    1
# 5d7d23315720533e15c3b1ee    2
# 5d7d405e5720533e15c3b1f3    3
# 5d80dfbc6c53455f896e600e    4
# dtype: int64

# %%
def item(id):
    return posts.loc[posts['post_id'] == id]['title'].tolist()[0]

# %%
def get_recommendations(postid, num, indices):
    idx = indices[postid]
    sim_scores = list(enumerate(cosine_similarities[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num+1]
    # print(sim_scores)
    indices = [i[0] for i in sim_scores]
    print("Recommending " + str(num) + " posts similar to \"" + item(postid) + "\" ...")
    return posts.iloc[indices]

# %%
get_recommendations('5eac305f10426255a7aa9dd3', 10, indices)
# Out:
# Recommending 10 posts similar to "She got a new hairstyle! Photo by Chirag" ...
#                       post_id                    title     category post_type
# 23   5dde6a91369b28584ecca156             Spirituality  Photography   artwork
# 62   5e3ab644eab55d319938a72d               Travelling  Photography   artwork
# 175  5e7df068a3258347b42f2125               screw town  Photography   artwork
# 176  5e7df283a3258347b42f2128                   screw2  Photography   artwork
# 205  5e8307ada3258347b42f23ec                Aesthetic  Photography   artwork
# 206  5e8308c4a3258347b42f23ed              Quarantined  Photography   artwork
# 207  5e8309a9a3258347b42f23f2                   Bloom🌸  Photography   artwork
# 208  5e830a6ca3258347b42f23f6                    Dog❤️  Photography   artwork
# 212  5e84657da3258347b42f2452            Leap of faith  Photography   artwork
# 217  5e8837fba3258347b42f255b  The silence that shouts  Photography   artwork

# %%
get_recommendations('5d6d39567fa40e1417a4931c', 10, indices)
# Out:
# Recommending 10 posts similar to "Ml and AI" ...
#                       post_id  \
# 122  5e5bdf4fd701ab08af792bfd
# 170  5e7c78fdcfc8b713f5ac7daa
# 186  5e81a4f2a3258347b42f21d3
# 224  5e897ab4a3258347b42f25ca
# 450  5ecd5d417023451e662235c5
# 454  5ecf818376027d35905cbf03
# 455  5ecf96e876027d35905cbf46
# 456  5ecfa0ca76027d35905cbf57
# 486  5ed2502b76027d35905cc7db
# 169  5e7bd922cfc8b713f5ac7da9
#
#                                                  title  \
# 122                            Artificial Intelligence
# 170                                       Types Of AI.
# 186  7 Best Python Data Science Courses & Certifica...
# 224  10 Best Artificial Intelligence (AI) Courses O...
# 450             Machine Learning”&“Operations" (MlOps)
# 454                                 GAN's INTRODUCTION
# 455                                      GAN's Part(2)
# 456                 Recommend Systems Machine Learning
# 486                                        Learning...
# ...

# %%
posts.head()
# Out:
#                     post_id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 4  5d80dfbc6c53455f896e600e   How Competition law evolved?
#
#                                             category post_type
# 0                                Plant Biotechnology      blog
# 1  Artificial Intelligence|Machine Learning|Infor...      blog
# 2                                  Operating Systems      blog
# 3                                           Drawings   artwork
# 4                                   Competition Laws      blog

# %%
posts['soup'] = posts['title'] + " " +posts['category'] + " " +posts['post_type']
posts.head()
# Out:
#                     post_id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 4  5d80dfbc6c53455f896e600e   How Competition law evolved?
#
#                                             category post_type  \
# 0                                Plant Biotechnology      blog
# 1  Artificial Intelligence|Machine Learning|Infor...      blog
# 2                                  Operating Systems      blog
# 3                                           Drawings   artwork
# 4                                   Competition Laws      blog
#
#                                                 soup
# 0               hello there Plant Biotechnology blog
# 1  Ml and AI Artificial Intelligence|Machine Lear...
# 2  What is an Operating System ? Operating System...
# ...

# %%
tf = TfidfVectorizer(analyzer='word', sublinear_tf=True, ngram_range=(1, 8), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(posts['soup'])
tfidf_matrix.shape
# Out:
# (493, 9234)

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_similarities[0]
# Out:
# array([1.        , 0.00500228, 0.01048471, 0.        , 0.00709757,
#        0.00709386, 0.0060751 , 0.00868397, 0.01349195, 0.00802797,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.00842108, 0.        , 0.00711724, 0.        ,
#        0.        , 0.        , 0.00643514, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.00810718, 0.        ,
#        0.        , 0.00713905, 0.        , 0.00704041, 0.        ,
#        0.00531304, 0.00607756, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.00810718, 0.00398069,
#        0.        , 0.        , 0.        , 0.00579384, 0.01038532,
#        0.00547773, 0.00446786, 0.00663773, 0.00573105, 0.00580979,
#        0.00650094, 0.00694541, 0.00506902, 0.00436214, 0.00661031,
#        0.0051112 , 0.00694541, 0.        , 0.00799855, 0.00792602,
#        0.        , 0.00599686, 0.00522975, 0.00662211, 0.00702204,
# ...
